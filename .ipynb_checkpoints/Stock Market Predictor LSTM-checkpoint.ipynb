# %% [markdown]
# # Exploratory Analysis - Predicting Stock Market Close Prices using LSTM
# By Ganel R. Nallamilli
#
# ***
# ## Contents
# - **1. Introduction**
#     - 1.1 Aims and Purpose
#     - 1.2 Imports
#     - 1.3 Building the Model
#     - 1,4 Helper Functions
# - **2. Data Preparation**
#     - 2.1 Loading the Data
#     - 2.2 Adding Indicators
#     - 2.3 Train/Test Split
# - **3. Training**
#     - 3.1 Training Model
# - **4. Results**
#     - 4.1 Metrics
#     - 4.2 Prediction Graph
#     - 4.3 Train/Test Loss Graph
#     - 4.4 Learning Rate Graph
#     - 4.5 Correlations
# - **5. Optimization**
#     - 5.1 Bayesian Optimization
# - **5. Conclusion**
#
#
# ***
#
# # 1. Introduction
# ## 1.1 Aims and Purpose
# This project aims to see how well LSTMs can predict a stock market close price only using previous-day data. There are multiple articles which use this method to predict stock prices, however, I suspect the output is often misinterpreted. We will only be analysing one timeframe of one stock in this notebook but feel free to change the variables and explore a new stock.
#
# This exploratory analysis is part of my web app project, which provides a user-friendly interface for users to change model parameters and analyse the output.
#
# ## 1.2 Imports
#
# Make sure you install the requirements.txt and import the libraries below.

# %%
import yfinance as yf
import torch 
import torch.nn as nn
import pandas as pd
from tqdm.auto import tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau,ExponentialLR
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
import math
from torch.autograd import Variable 
from datetime import datetime
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import numpy as np
import optuna
import warnings
import json 
warnings.filterwarnings("ignore", category=UserWarning, module=r"torch.optim.lr_scheduler")
torch.manual_seed(1)
np.random.seed(1)
torch.cuda.manual_seed(1)

# %% [markdown]
# ## 1.3 Building the Model
#
# I assume you are already familiar with the LSTM architecture, if you are not please research the basic architecture to aid to understanding - there are  lots of resources online. In this proect we implement the LSTM with pytorch, we then then use fully connected layers to bring our output to a dimensionality of 1 (which is the predicted closing price).

# %%
class LSTM1(nn.Module):
    def __init__(self, num_classes, input_size, hidden_size, num_layers, seq_length):
        super(LSTM1, self).__init__()
        self.num_classes = num_classes #number of classes
        self.num_layers = num_layers #number of layers
        self.input_size = input_size #input size
        self.hidden_size = hidden_size #hidden state
        self.seq_length = seq_length #sequence length

        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size,
                          num_layers=num_layers, batch_first=True) #lstm
        self.fc_1 =  nn.Linear(hidden_size, 128) #fully connected 1
        self.fc_2 = nn.Linear(128, num_classes) #fully connected last layer

        self.relu = nn.ReLU()
    
    def forward(self,x):
        h_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #hidden state
        c_0 = Variable(torch.zeros(self.num_layers, x.size(0), self.hidden_size)) #internal state
        # Propagate input through LSTM
        output, (hn, cn) = self.lstm(x, (h_0, c_0)) #lstm with input, hidden, and internal state
        hn = hn[-1]
        hn = hn.view(-1, self.hidden_size) #reshaping the data for Dense layer next
        out = self.relu(hn)
        out = self.relu(self.fc_1(out)) #first Dense
        out = self.fc_2(out) 
        return out

# %% [markdown]
# ## 1.3 Helper Functions
# Some useful functions which will help us in this project. We define the function which splits our dataset to train/test and a function which allows us to calculate the corrolation between the previous day features with the closing price.

# %%
def split_train_test(data,training_split = 0.8):
    data = data.copy()
    X = data
    y = data[['Close']]

    X_lagged = X.iloc[:-1]
    y = y.iloc[1:]

    training_percentage = int(training_split * len(X_lagged))

    features_used = ', '.join(X_lagged.columns)
    num_of_features = len(X_lagged.columns)

    mm = MinMaxScaler()
    ss = StandardScaler()
    X_ss = ss.fit_transform(X_lagged)
    y_mm = mm.fit_transform(y)

    X_train = X_ss[:training_percentage, :]
    X_test = X_ss[training_percentage:, :]

    y_train = y_mm[:training_percentage, :]
    y_test = y_mm[training_percentage:, :] 

    X_train_tensors = Variable(torch.Tensor(X_train))
    X_test_tensors = Variable(torch.Tensor(X_test))

    y_train_tensors = Variable(torch.Tensor(y_train))
    y_test_tensors = Variable(torch.Tensor(y_test)) 


    X_train_tensors = torch.reshape(X_train_tensors,   (X_train_tensors.shape[0], 1, X_train_tensors.shape[1]))
    X_test_tensors = torch.reshape(X_test_tensors,  (X_test_tensors.shape[0], 1, X_test_tensors.shape[1])) 

    return X_train_tensors, y_train_tensors, X_test_tensors, y_test_tensors,mm,features_used,num_of_features,X_lagged,y,ss

def calculate_correlations(x_clean,y_clean):
    x_clean = x_clean.copy()
    y_clean = y_clean.copy()
    x_clean['next_close'] = y_clean['Close'].to_list()
    correlation_matrix = x_clean.corr()
    correlations_with_single_var = correlation_matrix['next_close'].drop('next_close')
    features = list(correlations_with_single_var.index)
    corrolation_values = list(correlations_with_single_var.values)
    corrolation_values = [abs(x) for x in corrolation_values]
    corrolation_values, features = zip(*sorted(list(zip(corrolation_values,features)),reverse=True))
    return features,corrolation_values

# %% [markdown]
# # 2. Data Preparation
# ## 2.1 Loading the Data
#
# In this analysis we will be looking at google stock 'goog' in the timeframe between '2020-06-15' - '2024-08-02'

# %%
# Type ticker and date range you'd like to analyse.
ticker = 'goog'

# year-month-day
start_date = '2020-06-15'
end_date = '2024-08-02'

# Converts the start time to a month earlier as some indictors require past data.
date_obj = datetime.strptime(start_date, '%Y-%m-%d')
one_month_before = date_obj - relativedelta(months=1)
one_month_before_str = one_month_before.strftime('%Y-%m-%d')

# Fetches the stock data. Outputs contains, Open, Close, Volume, Low, High, Adj Close.
data_stock = yf.download(ticker, start=one_month_before_str, end= end_date)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# ## 2.2 Adding Indicators
# In the indicator set we list all the available technical indictors we can add to the data; which we will later train on. Feel free to remove any indicators you don't want the model to train on.

# %%
# Indictors you'd like to use in the model
# List of available indicators: '26_ema','21_ema','9_ema','high','low','adj_close','open','volume','upper_bollinger_bands','lower_bollinger_bands', 'macd','signal','SMA20'
indicators = set(['26_ema','21_ema','9_ema','high','low','adj_close','open','volume','upper_bollinger_bands','lower_bollinger_bands', 'macd','signal','SMA20'])

# %% [markdown]
# The method below adds all the indicators selected to the stock dataframe.

# %%
# Adds indicators to the dataframe.
if 'macd' in indicators or 'signal' in indicators:
    data_stock['EMA12'] = data_stock['Close'].ewm(span=12, adjust=False).mean()
    data_stock['EMA26'] = data_stock['Close'].ewm(span=26, adjust=False).mean()
    data_stock['MACD'] = data_stock['EMA12'] - data_stock['EMA26']
    data_stock['Signal Line'] = data_stock['MACD'].ewm(span=9, adjust=False).mean()
    data_stock = data_stock.drop(columns = ['EMA12','EMA26'])
if 'MACD' in data_stock and 'macd' not in indicators:
    data_stock = data_stock.drop(columns = ['MACD'])
if 'Signal Line' in data_stock and 'signal' not in indicators:
    data_stock = data_stock.drop(columns = ['Signal Line'])
if '26_ema' in indicators:
    data_stock['26 EMA'] = data_stock['Close'].ewm(span=26, adjust=False).mean()
if '21_ema' in indicators:
    data_stock['21 EMA'] = data_stock['Close'].ewm(span=21, adjust=False).mean()
if '9_ema' in indicators:
    data_stock['9 EMA'] = data_stock['Close'].ewm(span=9, adjust=False).mean()
if 'upper_bollinger_bands' in indicators or 'lower_bollinger_bands' in indicators:
    data_stock['SMA20'] = data_stock['Close'].rolling(window=20).mean()
    data_stock['SD20'] = data_stock['Close'].rolling(window=20).std()
    data_stock['Upper Bollinger Band'] = data_stock['SMA20'] + 2 * data_stock['SD20']
    data_stock['Lower Bollinger Band'] = data_stock['SMA20'] - 2 * data_stock['SD20']
    data_stock = data_stock.drop(columns = ['SMA20','SD20'])
if 'Upper Bollinger Band' in data_stock and 'upper_bollinger_bands' not in indicators:
    data_stock = data_stock.drop(columns = ['Upper Bollinger Band'])
if 'Lower Bollinger Band' in data_stock and 'lower_bollinger_bands' not in indicators:
    data_stock = data_stock.drop(columns = ['Lower Bollinger Band'])
if 'SMA20' in indicators:
    data_stock['20 SMA'] = data_stock['Close'].rolling(window=20).mean()
if 'high' not in indicators:
    data_stock = data_stock.drop(columns = ['High'])
if 'low' not in indicators:
    data_stock = data_stock.drop(columns = ['Low'])
if 'adj_close' not in indicators:
    data_stock = data_stock.drop(columns = ['Adj Close'])
if 'volume' not in indicators:
        data_stock = data_stock.drop(columns = ['Volume'])
if 'open' not in indicators:
    data_stock = data_stock.drop(columns = ['Open'])

#Drops any columns with NaNs.
data_stock = data_stock.dropna()

#Filters data such that it only contains data from the start date.
start_date_obj = pd.to_datetime(start_date)
data_stock = data_stock[data_stock.index >= start_date_obj]

# %% [markdown]
# We can now look at the dataframe, and we see all the indicators have been added.

# %%
data_stock
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-06-15   69.540001   71.239998   69.396004   70.992500   70.911804
# 2020-06-16   72.261002   72.750999   71.294998   72.136002   72.054008
# 2020-06-17   72.358002   73.000000   71.569000   72.556000   72.473526
# 2020-06-18   72.458000   72.570503   71.350502   71.797997   71.716385
# 2020-06-19   72.199997   72.389999   71.067497   71.585999   71.504631
# ...                ...         ...         ...         ...         ...
# 2024-07-26  168.770004  169.839996  165.865005  168.679993  168.679993
# 2024-07-29  170.500000  172.160004  169.720001  171.130005  171.130005
# 2024-07-30  171.830002  172.949997  170.119995  171.860001  171.860001
# 2024-07-31  174.919998  175.910004  171.720001  173.149994  173.149994
# 2024-08-01  171.979996  175.679993  170.509995  172.449997  172.449997
#
#               Volume      MACD  Signal Line      26 EMA      21 EMA  \
# Date
# 2020-06-15  30078000  0.573868     0.706642   70.723127   70.926773
# 2020-06-16  34184000  0.598289     0.684971   70.827784   71.036703
# 2020-06-17  30992000  0.644108     0.676798   70.955800   71.174821
# 2020-06-18  31638000  0.612198     0.663878   71.018185   71.231473
# 2020-06-19  63158000  0.563309     0.643764   71.060245   71.263703
# ...              ...       ...          ...         ...         ...
# 2024-07-26  25150100 -1.972672     0.433845  180.707774  180.589781
# 2024-07-29  13768900 -2.433223    -0.139569  179.998310  179.729802
# 2024-07-30  13681400 -2.708091    -0.653273  179.395472  179.014365
# 2024-07-31  15650200 -2.789676    -1.080554  178.932844  178.481241
# 2024-08-01  17177800 -2.877645    -1.439972  178.452633  177.932946
#
#                  9 EMA  Upper Bollinger Band  Lower Bollinger Band      20 SMA
# Date
# 2020-06-15   71.359507             73.314182             68.792593   71.053387
# 2020-06-16   71.514806             73.331419             69.069257   71.200338
# 2020-06-17   71.723045             73.245482             69.543369   71.394425
# 2020-06-18   71.738035             73.257037             69.678013   71.467525
# 2020-06-19   71.707628             73.216811             69.862839   71.539825
# ...                ...                   ...                   ...         ...
# 2024-07-26  177.216561            197.332859            170.228142  183.780501
# 2024-07-29  175.999250            197.854116            168.477886  183.166001
# 2024-07-30  175.171400            198.045890            167.023112  182.534501
# 2024-07-31  174.767119            197.790725            165.932276  181.861501
# 2024-08-01  174.303694            197.350379            164.878622  181.114500
#
# [1040 rows x 14 columns]

# %% [markdown]
# ## 2.3 Train/Test Split
# Now we have a dataset, we split our data into training and testing...

# %%
training_split = 0.8
X_train, y_train, X_test, y_test,scaler,features_used,num_of_features,x_clean,y_clean,data_scaler = split_train_test(data_stock, training_split = training_split)

# %% [markdown]
# # 3. Training
# ## 3.1 Training Model
# Here we set the hyperparameters for our model, these metrics may need to be changed and refined, however, the optimal hyperparameters can be found during Bayesian optimization later.
#
# **learning_rate** - Learning rate of the model
#
# **num_epochs** - Maximum number of epochs used in training
#
# **patience** - The number of epochs allowed to be trained without improvement in the test loss before training stops (relates to preventing overfitting)
#
# **ReduceLROnPlateau_factor** - The factor the scheduler reduces the learning rate by
#
# **ReduceLROnPlateau_patience** - The number of epochs without improvement of the test loss before the scheduler decreases the learning rate
#
# **hidden_size** - Hidden size of the LSTM model
#
# **num_layers** - Number of stacked LSTMs used, if more than 1 you may want to introduce a dropout parameter.

# %%
learning_rate = 0.00001 
num_epochs = 30000
patience = 100
ReduceLROnPlateau_factor = 0.9
ReduceLROnPlateau_patience = 10

hidden_size = 25 #number of features in hidden state
num_layers = 1 #number of stacked lstm layers

# %% [markdown]
# The code below trains the model... if you are happy with the hyperparameters above run the code below.

# %%
input_size = num_of_features #number of features (Do not change)
num_classes = 1 #number of output classes (Do not change)
model = LSTM1(num_classes, input_size, hidden_size, num_layers, X_train.shape[1])
criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) 
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=ReduceLROnPlateau_factor, patience=ReduceLROnPlateau_patience)
patience = patience

train_loss_array = []
test_loss_array = []
learning_rates = []
models = []
epochs_with_no_improvements = 0
best_loss = float('infinity')
best_model = None
epoch_tqdm = tqdm(range(num_epochs))

for epoch in epoch_tqdm:
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train) #forward pass
    
    # obtain the loss function
    loss = criterion(outputs, y_train)
    
    loss.backward() #calculates the loss of the loss function
    
    optimizer.step() #improve from loss, i.e backprop
    train_loss_array.append(loss.item())
    models.append(model)

    model.eval()
    with torch.no_grad():
        y_test_pred = model(X_test)
        loss_test = criterion(y_test_pred, y_test)
        test_loss_array.append(loss_test.item())

    scheduler.step(loss_test)


    current_lr = optimizer.param_groups[0]['lr']
    learning_rates.append(current_lr)

    epoch_tqdm.set_postfix(test_loss=float(loss_test.item()),train_loss=float(loss.item()), no_improvement = epochs_with_no_improvements)

    if loss_test < best_loss:
        best_loss = loss_test
        epochs_with_no_improvements = 0
        best_model = model
    else:
        epochs_with_no_improvements += 1


    if epochs_with_no_improvements == patience:
        break

    model.train()
# Out:
#   0%|          | 0/30000 [00:00<?, ?it/s]

# %% [markdown]
# # 4. Results
#
# Now the model is trained we can now inspect the performance of our trained model. We need to extract the predicted close price from the model by feeding in data and converting the output back to the unscaled close price values so we can compare it to the true close price values.

# %%
best_model.eval()
with torch.no_grad():
    test_y_pred = best_model(X_test)
    train_x_pred = best_model(X_train)

true_pred_close_test = scaler.inverse_transform(test_y_pred)
y_test_unscaled = scaler.inverse_transform(y_test)
true_pred_close_train = scaler.inverse_transform(train_x_pred)

y_axis_close_test = list(true_pred_close_test.flatten())
y_axis_close_train = list(true_pred_close_train.flatten())

# %% [markdown]
# ## 4.1 Metrics
# We use the RMSE (can be interpreted as the average error difference from the true closing price and the predicted closing price) and r^2 values (which tells us about how well the model captures the variance of the close prices) to judge the performance of the model. We compare these values to a Naive model, which is siimply using 'yesterdays closing price as todays predicted closing price'.

# %%
RMSE = round(math.sqrt(metrics.mean_squared_error(y_test_unscaled.flatten(), true_pred_close_test.flatten())),5)
RMSE_naive = round(math.sqrt(metrics.mean_squared_error(y_test_unscaled.flatten(), list(data_stock['Close'].iloc[:-1])[len(true_pred_close_train):])),5)
r_squared = round(metrics.r2_score(y_test_unscaled.flatten(), true_pred_close_test.flatten()), 5)
r_squared_naive = round(metrics.r2_score(y_test_unscaled.flatten(), list(data_stock['Close'].iloc[:-1])[len(true_pred_close_train):]), 5)
print(f'RMSE: {RMSE} | Naive RMSE: {RMSE_naive}')
print(f'r^2: {r_squared} | Naive r^2: {r_squared_naive}')
# Out:
# RMSE: 3.76716 | Naive RMSE: 2.72565
# r^2: 0.95802 | Naive r^2: 0.97802

# %% [markdown]
# We see that our model has not been able to outperform the naive model.

# %% [markdown]
# ## 4.2 Prediction Graph
#
# We now plot the predicted close prices against the true close price. The Naive model is plotted for comparison.

# %%
days_number = [i+1 for i in range(len(dates))]
plt.figure(figsize =(14,7))
plt.plot(days_number,data_stock['Close'], label =f'{ticker.upper()} Close Price', marker = '.', color = 'blue')
plt.plot(days_number[1:],list(data_stock['Close'].iloc[:-1]), label =f'Naive Model', marker = '.', color = 'purple')
plt.plot(days_number[len(dates_train_x_axis)+1:],y_axis_close_test, label =f'Test Prediction', marker = '.', color = 'red')
plt.plot(days_number[1:len(dates_train_x_axis)+1],y_axis_close_train, label =f'Train Prediction', marker = '.', color = 'green')
plt.ylabel('Close Prices')
plt.xlabel('Days')
plt.title(ticker.upper())
plt.legend()
plt.show()

# %% [markdown]
# From the graph, it looks like our model can accurately predict the close prices, however we know that from our metrics we know the model cannot beat the naive model. Lets take a closer look into the test data...

# %%
days_number = [i+1 for i in range(len(dates))]
plt.figure(figsize =(14,7))
plt.plot(days_number[len(dates_train_x_axis)+1:],data_stock['Close'].iloc[len(dates_train_x_axis)+1:], label =f'{ticker.upper()} Close Price', marker = '.', color = 'blue')
plt.plot(days_number[1:][len(dates_train_x_axis)+1:],list(data_stock['Close'].iloc[:-1])[len(dates_train_x_axis)+1:], label =f'Naive Model', marker = '.', color = 'purple')
plt.plot(days_number[len(dates_train_x_axis)+1:],y_axis_close_test, label =f'Test Prediction', marker = '.', color = 'red')
plt.ylabel('Close Prices')
plt.xlabel('Days')
plt.title(ticker.upper())
plt.legend()
plt.show()

# %% [markdown]
# We see that or model generally picks up the trends in the close prices however is unable to make accurate predictions. Moreover, a more important detail to notice is that the model seems to lag behind by one day. We see that the predicted close prices closely mimics the previous day closing price rather than establishing a new trend based off the available information. This suggests that the previous day price, contains no deeper information to help predict future closing prices.

# %% [markdown]
# ## 4.3 Train/Test Loss Graph
#
# An important graph to look at when training a model is the train/test loss curves as it gives us an insight into if the model has finished training, and if any overfitting as occured.

# %%
plt.figure(figsize =(14,7))
plt.plot(train_loss_array, label = 'Train Loss', marker = '.')
plt.plot(test_loss_array, label = 'Test Loss', marker = '.')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# From the graph, we observe that both losses plateau at a similar value. This indicates that the model has likely found a minimum that effectively reduces both the training and testing losses to a comparable level and is generally an indicator that the training process is complete.

# %% [markdown]
# ## 4.4 Learning Rate Graph
#
# We can also view how the learning rate changes throughout training...

# %%
plt.figure(figsize =(14,7))
plt.plot(learning_rates, label = 'Learning Rate', marker = '.')
plt.ylabel('Learning Rate')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ## 4.5 Correlations

# %%
corro_features,corrolation_values = calculate_correlations(x_clean,y_clean)

# %% [markdown]
# ## Metrics

# %%
print(f'RMSE: {RMSE} | Naive RMSE: {RMSE_naive}')
print(f'r^2: {r_squared} | Naive r^2: {r_squared_naive}')
# Out:
# RMSE: 6.86128 | Naive RMSE: 2.72565
# r^2: 0.86074 | Naive r^2: 0.97802

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Predictions

# %%
days_number = [i+1 for i in range(len(dates))]
plt.figure(figsize =(14,7))
plt.plot(days_number,data_stock['Close'], label =f'{ticker.upper()} Close Price', marker = '.', color = 'blue')
plt.plot(days_number[1:],list(data_stock['Close'].iloc[:-1]), label =f'Naive Model', marker = '.', color = 'purple')
plt.plot(days_number[len(dates_train_x_axis)+1:],y_axis_close_test, label =f'Test Prediction', marker = '.', color = 'red')
plt.plot(days_number[1:len(dates_train_x_axis)+1],y_axis_close_train, label =f'Train Prediction', marker = '.', color = 'green')
plt.ylabel('Close Prices')
plt.xlabel('Dates')
plt.legend()
plt.show()

# %% [markdown]
# ### Train/Test Loss

# %%
plt.figure(figsize =(14,7))
plt.plot(train_loss_array, label = 'Train Loss', marker = '.')
plt.plot(test_loss_array, label = 'Train Loss', marker = '.')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ### Learning Rate

# %%
plt.figure(figsize =(14,7))
plt.plot(learning_rates, label = 'Learning Rate', marker = '.')
plt.ylabel('Learning Rate')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ### Correlations

# %%
corro_colours = ['green' if x>0.5 else 'red' for x in corrolation_values]
plt.figure(figsize = (10,5))
plt.bar(corro_features,corrolation_values,color=corro_colours)
plt.xticks(rotation='vertical')
plt.xlabel('Features')
plt.ylabel('Correlation Coeff')
plt.show()

# %% [markdown]
# # Bayesian Optimization

# %%
def objective(trial):
    learning_rate = trial.suggest_float('learning_rate', 0.000001,0.0001)
    hidden_size = trial.suggest_int('hidden_size', 16,200)
    gamma = trial.suggest_float('gamma', 0.85, 0.99)

    num_epochs = 30000
    training_split = 0.8
    X_train, y_train, X_test, y_test,scaler,features_used,num_of_features,x_clean,y_clean,data_scaler = split_train_test(data_stock, training_split = training_split)
    
    input_size = num_of_features #number of features
    num_layers = 1 #number of stacked lstm layers
    num_classes = 1 #number of output classes 
    
    model = LSTM1(num_classes, input_size, hidden_size, num_layers, X_train.shape[1])
    criterion = torch.nn.MSELoss()    # mean-squared error for regression
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate) 
    scheduler = ExponentialLR(optimizer, gamma=gamma)
    
    patience = 50
    
    train_loss_array = []
    test_loss_array = []
    learning_rates = []
    models = []
    epochs_with_no_improvements = 0
    best_loss = float('infinity')
    best_model = None
    
    for epoch in range(num_epochs):
        model.train()
        optimizer.zero_grad()
        outputs = model(X_train) #forward pass
        
        # obtain the loss function
        loss = criterion(outputs, y_train)
        
        loss.backward() #calculates the loss of the loss function
        
        optimizer.step() #improve from loss, i.e backprop
        train_loss_array.append(loss.item())
        models.append(model)
    
        model.eval()
        with torch.no_grad():
            y_test_pred = model(X_test)
            loss_test = criterion(y_test_pred, y_test)
            test_loss_array.append(loss_test.item())
    
        scheduler.step(loss_test)
    
        current_lr = optimizer.param_groups[0]['lr']
        learning_rates.append(current_lr)
    
    
        if loss_test < best_loss:
            best_loss = loss_test
            epochs_with_no_improvements = 0
            best_model = model
        else:
            epochs_with_no_improvements += 1
    
    
        if epochs_with_no_improvements == patience:
            break
    
        model.train()
    return loss_test.item()
    
    
    
study = optuna.create_study(direction='minimize')  # or 'maximize' depending on your objective
study.optimize(objective, n_trials=200)
print("Best hyperparameters:", study.best_params)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [I 2024-08-09 03:21:52,285] A new study created in memory with name: no-name-d8ebfe0b-ccd5-493d-b89b-86f47a90ed70
# [I 2024-08-09 03:21:55,472] Trial 0 finished with value: 0.0051172105595469475 and parameters: {'learning_rate': 5.566275634943074e-05, 'hidden_size': 97, 'gamma': 0.9604463773330489}. Best is trial 0 with value: 0.0051172105595469475.
# [I 2024-08-09 03:22:50,246] Trial 1 finished with value: 0.004400279838591814 and parameters: {'learning_rate': 2.809838768912962e-06, 'hidden_size': 44, 'gamma': 0.9332071855884346}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:23:04,495] Trial 2 finished with value: 0.006223197095096111 and parameters: {'learning_rate': 3.779203290409211e-05, 'hidden_size': 28, 'gamma': 0.8915161273545666}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:23:07,180] Trial 3 finished with value: 0.013067909516394138 and parameters: {'learning_rate': 9.532061106409737e-05, 'hidden_size': 118, 'gamma': 0.8690554987837753}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:23:11,232] Trial 4 finished with value: 0.011423618532717228 and parameters: {'learning_rate': 9.955489398448506e-05, 'hidden_size': 167, 'gamma': 0.8958188124455799}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:23:45,460] Trial 5 finished with value: 0.005877448711544275 and parameters: {'learning_rate': 1.2443303715468163e-05, 'hidden_size': 162, 'gamma': 0.9496538387072344}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:23:47,370] Trial 6 finished with value: 0.013120767660439014 and parameters: {'learning_rate': 8.50879558218791e-05, 'hidden_size': 164, 'gamma': 0.8775041886474111}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:24:46,534] Trial 7 finished with value: 0.0048505933955311775 and parameters: {'learning_rate': 6.433029918026936e-06, 'hidden_size': 124, 'gamma': 0.9427590478953989}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:24:57,635] Trial 8 finished with value: 0.019562795758247375 and parameters: {'learning_rate': 2.1219965822825082e-05, 'hidden_size': 170, 'gamma': 0.8588223418945897}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:25:34,615] Trial 9 finished with value: 0.0057893432676792145 and parameters: {'learning_rate': 1.2196803009736203e-05, 'hidden_size': 185, 'gamma': 0.9608369809628318}. Best is trial 1 with value: 0.004400279838591814.
# [I 2024-08-09 03:25:36,810] Trial 10 finished with value: 0.004252379294484854 and parameters: {'learning_rate': 5.760907150524571e-05, 'hidden_size': 16, 'gamma': 0.9863463955801243}. Best is trial 10 with value: 0.004252379294484854.
# [I 2024-08-09 03:25:39,611] Trial 11 finished with value: 0.0040182811208069324 and parameters: {'learning_rate': 6.157101128239803e-05, 'hidden_size': 27, 'gamma': 0.9221296447204711}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:25:45,174] Trial 12 finished with value: 0.005586246959865093 and parameters: {'learning_rate': 6.647489815192101e-05, 'hidden_size': 59, 'gamma': 0.9894228827533114}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:25:51,882] Trial 13 finished with value: 0.005264783278107643 and parameters: {'learning_rate': 7.053188007393042e-05, 'hidden_size': 74, 'gamma': 0.9893956207165252}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:25:56,724] Trial 14 finished with value: 0.005456147715449333 and parameters: {'learning_rate': 3.8853910210708836e-05, 'hidden_size': 21, 'gamma': 0.9153117296605462}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:02,267] Trial 15 finished with value: 0.005472490563988686 and parameters: {'learning_rate': 5.508562885886938e-05, 'hidden_size': 17, 'gamma': 0.91429308222315}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:08,314] Trial 16 finished with value: 0.005292926449328661 and parameters: {'learning_rate': 6.985791425462683e-05, 'hidden_size': 82, 'gamma': 0.9740587910610682}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:17,501] Trial 17 finished with value: 0.0054336972534656525 and parameters: {'learning_rate': 4.0525637354105415e-05, 'hidden_size': 45, 'gamma': 0.9253671778308598}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:19,902] Trial 18 finished with value: 0.006777848117053509 and parameters: {'learning_rate': 8.109478249685359e-05, 'hidden_size': 44, 'gamma': 0.9000835005141663}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:23,144] Trial 19 finished with value: 0.00847818236798048 and parameters: {'learning_rate': 4.876914405324708e-05, 'hidden_size': 142, 'gamma': 0.9738225488102966}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:25,278] Trial 20 finished with value: 0.008264387957751751 and parameters: {'learning_rate': 6.284721248306007e-05, 'hidden_size': 72, 'gamma': 0.8532125810559145}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:31,338] Trial 21 finished with value: 0.007396142929792404 and parameters: {'learning_rate': 2.6464134244539434e-05, 'hidden_size': 43, 'gamma': 0.9320189181117938}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:33,589] Trial 22 finished with value: 0.006653526332229376 and parameters: {'learning_rate': 4.762718105112394e-05, 'hidden_size': 35, 'gamma': 0.9394977379868529}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:35,645] Trial 23 finished with value: 0.0053857071325182915 and parameters: {'learning_rate': 8.037695817235189e-05, 'hidden_size': 59, 'gamma': 0.9137111172587153}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:45,701] Trial 24 finished with value: 0.006601902190595865 and parameters: {'learning_rate': 2.9226549516449032e-05, 'hidden_size': 55, 'gamma': 0.9548528039783538}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:49,376] Trial 25 finished with value: 0.004142302554100752 and parameters: {'learning_rate': 6.112386921006447e-05, 'hidden_size': 17, 'gamma': 0.9262435096094784}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:54,053] Trial 26 finished with value: 0.005604537669569254 and parameters: {'learning_rate': 5.665962913945588e-05, 'hidden_size': 19, 'gamma': 0.9025362260201198}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:26:56,231] Trial 27 finished with value: 0.004673671443015337 and parameters: {'learning_rate': 7.60271853262977e-05, 'hidden_size': 31, 'gamma': 0.8808015344447}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:02,628] Trial 28 finished with value: 0.006967030931264162 and parameters: {'learning_rate': 6.022644647020311e-05, 'hidden_size': 95, 'gamma': 0.9238409024836861}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:09,426] Trial 29 finished with value: 0.005218629725277424 and parameters: {'learning_rate': 5.3170467819282107e-05, 'hidden_size': 98, 'gamma': 0.9644013628242606}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:20,497] Trial 30 finished with value: 0.00492459163069725 and parameters: {'learning_rate': 4.841478711580373e-05, 'hidden_size': 31, 'gamma': 0.9724222420974405}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:23,063] Trial 31 finished with value: 0.00950121134519577 and parameters: {'learning_rate': 6.35747787877195e-05, 'hidden_size': 50, 'gamma': 0.9395213471593811}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:32,363] Trial 32 finished with value: 0.006180049851536751 and parameters: {'learning_rate': 4.38292644362219e-05, 'hidden_size': 35, 'gamma': 0.9068810112793574}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:37,629] Trial 33 finished with value: 0.004030612297356129 and parameters: {'learning_rate': 3.066887734408624e-05, 'hidden_size': 17, 'gamma': 0.9293313632258747}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:42,324] Trial 34 finished with value: 0.011472208425402641 and parameters: {'learning_rate': 3.34343516859735e-05, 'hidden_size': 16, 'gamma': 0.9298124101413513}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:49,846] Trial 35 finished with value: 0.010402854532003403 and parameters: {'learning_rate': 7.271107206880058e-05, 'hidden_size': 28, 'gamma': 0.8898181959163863}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:52,223] Trial 36 finished with value: 0.017328180372714996 and parameters: {'learning_rate': 8.887209780354221e-05, 'hidden_size': 39, 'gamma': 0.9481404701983194}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:55,232] Trial 37 finished with value: 0.004714006558060646 and parameters: {'learning_rate': 5.82561219289715e-05, 'hidden_size': 24, 'gamma': 0.9225560346207259}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:27:59,472] Trial 38 finished with value: 0.004401137586683035 and parameters: {'learning_rate': 3.556610831581192e-05, 'hidden_size': 27, 'gamma': 0.909987640722309}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:28:04,142] Trial 39 finished with value: 0.005889045540243387 and parameters: {'learning_rate': 4.403252470331068e-05, 'hidden_size': 59, 'gamma': 0.8892981909012365}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:28:12,647] Trial 40 finished with value: 0.009883592836558819 and parameters: {'learning_rate': 1.5912891120227108e-05, 'hidden_size': 69, 'gamma': 0.9809323235835297}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:28:31,268] Trial 41 finished with value: 0.004318530205637217 and parameters: {'learning_rate': 7.065179278708789e-06, 'hidden_size': 37, 'gamma': 0.9328852158639542}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:29:33,179] Trial 42 finished with value: 0.004315911326557398 and parameters: {'learning_rate': 2.291953274713406e-06, 'hidden_size': 25, 'gamma': 0.9360528846362738}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:29:40,250] Trial 43 finished with value: 0.007472411263734102 and parameters: {'learning_rate': 2.28183143522402e-05, 'hidden_size': 17, 'gamma': 0.9495132293617359}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:29:42,673] Trial 44 finished with value: 0.006410805508494377 and parameters: {'learning_rate': 6.618334008085357e-05, 'hidden_size': 132, 'gamma': 0.942474298885986}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:30:16,001] Trial 45 finished with value: 0.004412287380546331 and parameters: {'learning_rate': 4.256181315818403e-06, 'hidden_size': 26, 'gamma': 0.9185310808733579}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:30:29,548] Trial 46 finished with value: 0.00523983733728528 and parameters: {'learning_rate': 5.29603306635974e-05, 'hidden_size': 53, 'gamma': 0.92779060220751}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:30:44,501] Trial 47 finished with value: 0.0075986855663359165 and parameters: {'learning_rate': 1.4325188072463952e-05, 'hidden_size': 24, 'gamma': 0.9367877571431633}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:30:51,784] Trial 48 finished with value: 0.005801888648420572 and parameters: {'learning_rate': 1.8567188191967815e-05, 'hidden_size': 46, 'gamma': 0.9594838120966674}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:31:08,229] Trial 49 finished with value: 0.004193976987153292 and parameters: {'learning_rate': 8.35627142470531e-06, 'hidden_size': 16, 'gamma': 0.8702531748710528}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:31:30,334] Trial 50 finished with value: 0.005220856051892042 and parameters: {'learning_rate': 3.0021936417514977e-05, 'hidden_size': 153, 'gamma': 0.8646291157983393}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:32:55,618] Trial 51 finished with value: 0.007590650115162134 and parameters: {'learning_rate': 1.907772156093078e-06, 'hidden_size': 16, 'gamma': 0.8777985222103323}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:33:10,990] Trial 52 finished with value: 0.010517631657421589 and parameters: {'learning_rate': 8.894665100794677e-06, 'hidden_size': 34, 'gamma': 0.9184816999457341}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:33:34,768] Trial 53 finished with value: 0.005669531412422657 and parameters: {'learning_rate': 1.1673810243358413e-05, 'hidden_size': 24, 'gamma': 0.8959802378915649}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:33:40,552] Trial 54 finished with value: 0.010117173194885254 and parameters: {'learning_rate': 6.209619531250239e-05, 'hidden_size': 198, 'gamma': 0.9057674316513}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:33:42,804] Trial 55 finished with value: 0.006348193157464266 and parameters: {'learning_rate': 6.838441163109652e-05, 'hidden_size': 43, 'gamma': 0.9452083796296483}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:34:08,561] Trial 56 finished with value: 0.004885256290435791 and parameters: {'learning_rate': 2.4410511813063548e-05, 'hidden_size': 67, 'gamma': 0.9540921589902447}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:34:19,312] Trial 57 finished with value: 0.005558604374527931 and parameters: {'learning_rate': 7.506294185922721e-05, 'hidden_size': 22, 'gamma': 0.9348421094116139}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:34:35,717] Trial 58 finished with value: 0.008145720697939396 and parameters: {'learning_rate': 1.0191440525542813e-05, 'hidden_size': 115, 'gamma': 0.8831145567532397}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:34:59,393] Trial 59 finished with value: 0.005477169528603554 and parameters: {'learning_rate': 3.814162968003725e-06, 'hidden_size': 80, 'gamma': 0.9122483958204515}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:35:04,017] Trial 60 finished with value: 0.004518880043178797 and parameters: {'learning_rate': 4.419668725889023e-05, 'hidden_size': 39, 'gamma': 0.8695147736848439}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:35:59,861] Trial 61 finished with value: 0.004984025843441486 and parameters: {'learning_rate': 5.924537886431161e-06, 'hidden_size': 36, 'gamma': 0.9316048252955932}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:37:39,773] Trial 62 finished with value: 0.005657353904098272 and parameters: {'learning_rate': 1.0116426974692537e-06, 'hidden_size': 32, 'gamma': 0.9216349653821118}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:37:58,772] Trial 63 finished with value: 0.004022550769150257 and parameters: {'learning_rate': 8.012912538706148e-06, 'hidden_size': 22, 'gamma': 0.9367584571555496}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:01,597] Trial 64 finished with value: 0.005328403785824776 and parameters: {'learning_rate': 5.818178065283761e-05, 'hidden_size': 21, 'gamma': 0.9272639973081441}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:12,755] Trial 65 finished with value: 0.007210012525320053 and parameters: {'learning_rate': 1.4197466420888423e-05, 'hidden_size': 31, 'gamma': 0.9674805652645748}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:34,592] Trial 66 finished with value: 0.007385964505374432 and parameters: {'learning_rate': 1.9446453082441204e-05, 'hidden_size': 48, 'gamma': 0.852632810833675}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:39,334] Trial 67 finished with value: 0.005340067204087973 and parameters: {'learning_rate': 5.1363179782836475e-05, 'hidden_size': 20, 'gamma': 0.9807758813719571}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:41,517] Trial 68 finished with value: 0.008303861133754253 and parameters: {'learning_rate': 6.523612035621383e-05, 'hidden_size': 28, 'gamma': 0.9376815170120546}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:38:44,412] Trial 69 finished with value: 0.004426509607583284 and parameters: {'learning_rate': 6.046272882629633e-05, 'hidden_size': 16, 'gamma': 0.9163785430915885}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:39:09,073] Trial 70 finished with value: 0.00621903408318758 and parameters: {'learning_rate': 1.674616205270595e-05, 'hidden_size': 41, 'gamma': 0.9423754037433145}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:39:31,391] Trial 71 finished with value: 0.0043392302468419075 and parameters: {'learning_rate': 7.759278979480479e-06, 'hidden_size': 29, 'gamma': 0.9257380174449475}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:40:07,437] Trial 72 finished with value: 0.0050090826116502285 and parameters: {'learning_rate': 6.986244270151122e-06, 'hidden_size': 22, 'gamma': 0.9328721291968162}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:40:54,796] Trial 73 finished with value: 0.005210386589169502 and parameters: {'learning_rate': 1.1482003713658066e-05, 'hidden_size': 38, 'gamma': 0.9300475396549392}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:40:58,621] Trial 74 finished with value: 0.0047072903253138065 and parameters: {'learning_rate': 5.6294820148885586e-05, 'hidden_size': 16, 'gamma': 0.9218836616597956}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:41:24,563] Trial 75 finished with value: 0.00652790442109108 and parameters: {'learning_rate': 6.324844265940249e-06, 'hidden_size': 26, 'gamma': 0.9466095775256697}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:08,681] Trial 76 finished with value: 0.005132496356964111 and parameters: {'learning_rate': 3.5835802206513164e-06, 'hidden_size': 34, 'gamma': 0.9397604072679411}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:13,869] Trial 77 finished with value: 0.009074687026441097 and parameters: {'learning_rate': 4.01430257823023e-05, 'hidden_size': 52, 'gamma': 0.9523270474545634}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:24,679] Trial 78 finished with value: 0.005113999824970961 and parameters: {'learning_rate': 2.106199634584612e-05, 'hidden_size': 21, 'gamma': 0.9579675947043201}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:27,733] Trial 79 finished with value: 0.005771078635007143 and parameters: {'learning_rate': 5.3687308305250615e-05, 'hidden_size': 95, 'gamma': 0.9349023652508881}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:39,763] Trial 80 finished with value: 0.007847250439226627 and parameters: {'learning_rate': 7.084440972652524e-05, 'hidden_size': 30, 'gamma': 0.90941226320315}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:42:59,721] Trial 81 finished with value: 0.004251149948686361 and parameters: {'learning_rate': 7.953030496843334e-06, 'hidden_size': 28, 'gamma': 0.9262084026771729}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:43:16,412] Trial 82 finished with value: 0.004138090647757053 and parameters: {'learning_rate': 9.903756898951855e-06, 'hidden_size': 23, 'gamma': 0.9273189936738521}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:43:40,211] Trial 83 finished with value: 0.005278731696307659 and parameters: {'learning_rate': 1.3499253807187106e-05, 'hidden_size': 26, 'gamma': 0.9259476426433567}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:44:24,909] Trial 84 finished with value: 0.006227901205420494 and parameters: {'learning_rate': 9.133876838112455e-06, 'hidden_size': 20, 'gamma': 0.9171923920379647}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:44:32,580] Trial 85 finished with value: 0.004343501292169094 and parameters: {'learning_rate': 1.753675634189714e-05, 'hidden_size': 16, 'gamma': 0.9007658747565389}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:44:57,401] Trial 86 finished with value: 0.004084783606231213 and parameters: {'learning_rate': 4.560706392521898e-06, 'hidden_size': 24, 'gamma': 0.9213608245893875}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:14,049] Trial 87 finished with value: 0.005655411630868912 and parameters: {'learning_rate': 1.0040536774064201e-05, 'hidden_size': 32, 'gamma': 0.911449138467987}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:24,142] Trial 88 finished with value: 0.00493895448744297 and parameters: {'learning_rate': 2.6489790506249344e-05, 'hidden_size': 41, 'gamma': 0.9193434156334628}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:40,857] Trial 89 finished with value: 0.004377756733447313 and parameters: {'learning_rate': 1.575978513926565e-05, 'hidden_size': 23, 'gamma': 0.9144119417370343}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:45,106] Trial 90 finished with value: 0.00430332962423563 and parameters: {'learning_rate': 4.608037660929867e-05, 'hidden_size': 29, 'gamma': 0.9045781645851839}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:49,651] Trial 91 finished with value: 0.006068108137696981 and parameters: {'learning_rate': 4.94759206416194e-05, 'hidden_size': 30, 'gamma': 0.9228892138627801}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:45:52,728] Trial 92 finished with value: 0.008684536442160606 and parameters: {'learning_rate': 3.646282836578416e-05, 'hidden_size': 20, 'gamma': 0.8593324938750961}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:07,947] Trial 93 finished with value: 0.005865106359124184 and parameters: {'learning_rate': 3.1686484632212556e-05, 'hidden_size': 27, 'gamma': 0.9288070648582759}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:09,755] Trial 94 finished with value: 0.004113459959626198 and parameters: {'learning_rate': 6.444619563170551e-05, 'hidden_size': 35, 'gamma': 0.8945850923755648}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:11,053] Trial 95 finished with value: 0.005768340080976486 and parameters: {'learning_rate': 6.747899075256951e-05, 'hidden_size': 36, 'gamma': 0.8971570860065203}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:23,005] Trial 96 finished with value: 0.005192369222640991 and parameters: {'learning_rate': 6.306240167010247e-05, 'hidden_size': 46, 'gamma': 0.8745920085295119}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:25,992] Trial 97 finished with value: 0.011502559296786785 and parameters: {'learning_rate': 6.105659551008321e-05, 'hidden_size': 174, 'gamma': 0.8923513486569958}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:28,606] Trial 98 finished with value: 0.004130406770855188 and parameters: {'learning_rate': 6.427362345462987e-05, 'hidden_size': 19, 'gamma': 0.9087252442363382}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:34,451] Trial 99 finished with value: 0.007184434682130814 and parameters: {'learning_rate': 7.90985688876819e-05, 'hidden_size': 24, 'gamma': 0.9075946410813129}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:37,324] Trial 100 finished with value: 0.013160940259695053 and parameters: {'learning_rate': 6.457740157554945e-05, 'hidden_size': 19, 'gamma': 0.8862651118055175}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:46:39,435] Trial 101 finished with value: 0.004817258100956678 and parameters: {'learning_rate': 5.9441412270393255e-05, 'hidden_size': 16, 'gamma': 0.9249814436079701}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:47:07,032] Trial 102 finished with value: 0.005755142774432898 and parameters: {'learning_rate': 5.098995775688011e-06, 'hidden_size': 33, 'gamma': 0.9195638257865126}. Best is trial 11 with value: 0.0040182811208069324.
# [I 2024-08-09 03:47:09,660] Trial 103 finished with value: 0.00398518331348896 and parameters: {'learning_rate': 5.810998212189734e-05, 'hidden_size': 24, 'gamma': 0.985099321850392}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:11,208] Trial 104 finished with value: 0.008853825740516186 and parameters: {'learning_rate': 6.965977692786706e-05, 'hidden_size': 24, 'gamma': 0.9150513858298848}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:14,210] Trial 105 finished with value: 0.00729434983804822 and parameters: {'learning_rate': 5.5541987484523136e-05, 'hidden_size': 38, 'gamma': 0.9300157913748933}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:17,035] Trial 106 finished with value: 0.004506935831159353 and parameters: {'learning_rate': 5.777461125395742e-05, 'hidden_size': 20, 'gamma': 0.9232567778127009}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:30,875] Trial 107 finished with value: 0.0052995141595602036 and parameters: {'learning_rate': 1.1595021646222316e-05, 'hidden_size': 42, 'gamma': 0.8583461803798537}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:32,015] Trial 108 finished with value: 0.009919059462845325 and parameters: {'learning_rate': 9.733907176804504e-05, 'hidden_size': 28, 'gamma': 0.8685709794669697}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:37,480] Trial 109 finished with value: 0.005260876379907131 and parameters: {'learning_rate': 7.302320447545664e-05, 'hidden_size': 34, 'gamma': 0.8987243252843253}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:39,358] Trial 110 finished with value: 0.004130418412387371 and parameters: {'learning_rate': 6.195452706796445e-05, 'hidden_size': 24, 'gamma': 0.892837191423799}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:42,844] Trial 111 finished with value: 0.004467819817364216 and parameters: {'learning_rate': 6.551333690896705e-05, 'hidden_size': 24, 'gamma': 0.8861107919438063}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:46,173] Trial 112 finished with value: 0.01606064848601818 and parameters: {'learning_rate': 6.220206625003444e-05, 'hidden_size': 19, 'gamma': 0.8936120259924462}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:53,484] Trial 113 finished with value: 0.005180750507861376 and parameters: {'learning_rate': 6.763447916302933e-05, 'hidden_size': 27, 'gamma': 0.8760180121664537}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:56,166] Trial 114 finished with value: 0.007009618449956179 and parameters: {'learning_rate': 5.981928373496326e-05, 'hidden_size': 23, 'gamma': 0.9043259871754934}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:47:59,327] Trial 115 finished with value: 0.00814515445381403 and parameters: {'learning_rate': 6.370607715137209e-05, 'hidden_size': 32, 'gamma': 0.8799967520000496}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:48:04,812] Trial 116 finished with value: 0.006296148523688316 and parameters: {'learning_rate': 5.225123460577098e-05, 'hidden_size': 19, 'gamma': 0.913037729510358}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:48:09,124] Trial 117 finished with value: 0.006673182360827923 and parameters: {'learning_rate': 5.446080403704619e-05, 'hidden_size': 37, 'gamma': 0.9213124836671841}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:05,058] Trial 118 finished with value: 0.005109855905175209 and parameters: {'learning_rate': 2.746624100467849e-06, 'hidden_size': 103, 'gamma': 0.9278760827994471}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:24,103] Trial 119 finished with value: 0.005150779616087675 and parameters: {'learning_rate': 8.474413342613818e-06, 'hidden_size': 26, 'gamma': 0.9323947840491998}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:26,454] Trial 120 finished with value: 0.007348316255956888 and parameters: {'learning_rate': 7.242939626242743e-05, 'hidden_size': 88, 'gamma': 0.9832297074889409}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:34,176] Trial 121 finished with value: 0.005982054863125086 and parameters: {'learning_rate': 5.74444313786693e-05, 'hidden_size': 16, 'gamma': 0.987483974952816}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:37,688] Trial 122 finished with value: 0.004768336191773415 and parameters: {'learning_rate': 6.150255202479639e-05, 'hidden_size': 21, 'gamma': 0.9802129006234778}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:56,821] Trial 123 finished with value: 0.005101610440760851 and parameters: {'learning_rate': 5.745153207312449e-06, 'hidden_size': 30, 'gamma': 0.9715901115650768}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:49:59,767] Trial 124 finished with value: 0.00900186412036419 and parameters: {'learning_rate': 5.923831189849376e-05, 'hidden_size': 126, 'gamma': 0.9087764408157238}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:50:04,458] Trial 125 finished with value: 0.00552477827295661 and parameters: {'learning_rate': 5.624832597734415e-05, 'hidden_size': 23, 'gamma': 0.9248441916398976}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:50:24,861] Trial 126 finished with value: 0.00504910247400403 and parameters: {'learning_rate': 1.3030780998434158e-05, 'hidden_size': 18, 'gamma': 0.9161083634276995}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:50:26,796] Trial 127 finished with value: 0.0049167899414896965 and parameters: {'learning_rate': 6.908662161237137e-05, 'hidden_size': 28, 'gamma': 0.9873694264234975}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:51:51,526] Trial 128 finished with value: 0.09854661673307419 and parameters: {'learning_rate': 1.0535212342224723e-06, 'hidden_size': 16, 'gamma': 0.9781822945674551}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:51:59,150] Trial 129 finished with value: 0.007669874466955662 and parameters: {'learning_rate': 6.55099856425877e-05, 'hidden_size': 33, 'gamma': 0.9400361370045294}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:03,467] Trial 130 finished with value: 0.01707705669105053 and parameters: {'learning_rate': 4.980079845740419e-05, 'hidden_size': 145, 'gamma': 0.9018666547369758}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:07,294] Trial 131 finished with value: 0.004602300934493542 and parameters: {'learning_rate': 4.781847885574696e-05, 'hidden_size': 29, 'gamma': 0.9054941934343609}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:10,502] Trial 132 finished with value: 0.004544200375676155 and parameters: {'learning_rate': 6.351572964599056e-05, 'hidden_size': 22, 'gamma': 0.895292185055232}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:25,528] Trial 133 finished with value: 0.006171173416078091 and parameters: {'learning_rate': 4.2290728374972576e-05, 'hidden_size': 26, 'gamma': 0.8893035719183592}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:28,673] Trial 134 finished with value: 0.005453529767692089 and parameters: {'learning_rate': 4.568760083391431e-05, 'hidden_size': 20, 'gamma': 0.9841543461523555}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:38,743] Trial 135 finished with value: 0.005469655618071556 and parameters: {'learning_rate': 1.0185114138160662e-05, 'hidden_size': 30, 'gamma': 0.9195103598424968}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:41,530] Trial 136 finished with value: 0.006362870801240206 and parameters: {'learning_rate': 6.14449651992598e-05, 'hidden_size': 24, 'gamma': 0.9356044759824731}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:48,262] Trial 137 finished with value: 0.004727324936538935 and parameters: {'learning_rate': 8.967330971825164e-05, 'hidden_size': 35, 'gamma': 0.9760359572384066}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:49,819] Trial 138 finished with value: 0.006343832239508629 and parameters: {'learning_rate': 5.495370998982346e-05, 'hidden_size': 40, 'gamma': 0.9028131788655452}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:52:53,523] Trial 139 finished with value: 0.00976935587823391 and parameters: {'learning_rate': 6.64056287364927e-05, 'hidden_size': 16, 'gamma': 0.9636343316963661}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:53:13,569] Trial 140 finished with value: 0.004432606510818005 and parameters: {'learning_rate': 7.077646122851149e-06, 'hidden_size': 26, 'gamma': 0.9308328450897009}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:54:17,421] Trial 141 finished with value: 0.0061518060974776745 and parameters: {'learning_rate': 4.17469987132662e-06, 'hidden_size': 22, 'gamma': 0.9276189483792548}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:54:56,575] Trial 142 finished with value: 0.004369616042822599 and parameters: {'learning_rate': 3.56565596346238e-06, 'hidden_size': 30, 'gamma': 0.9335024045240019}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:55:10,044] Trial 143 finished with value: 0.0041715833358466625 and parameters: {'learning_rate': 8.132373092973206e-06, 'hidden_size': 21, 'gamma': 0.9371861399403021}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:55:21,813] Trial 144 finished with value: 0.007736556697636843 and parameters: {'learning_rate': 1.461575941928748e-05, 'hidden_size': 19, 'gamma': 0.9376681517810318}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:55:56,478] Trial 145 finished with value: 0.004892525263130665 and parameters: {'learning_rate': 1.0931263334408438e-05, 'hidden_size': 25, 'gamma': 0.943442557257611}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:56:00,378] Trial 146 finished with value: 0.004125055857002735 and parameters: {'learning_rate': 2.7176320419382456e-05, 'hidden_size': 21, 'gamma': 0.9231669895404991}. Best is trial 103 with value: 0.00398518331348896.
# [I 2024-08-09 03:56:12,436] Trial 147 finished with value: 0.0039343442767858505 and parameters: {'learning_rate': 8.509711491725397e-06, 'hidden_size': 20, 'gamma': 0.9235682389721885}. Best is trial 147 with value: 0.0039343442767858505.
# [I 2024-08-09 03:56:33,508] Trial 148 finished with value: 0.004050432238727808 and parameters: {'learning_rate': 8.334889449387052e-06, 'hidden_size': 20, 'gamma': 0.9238633221152037}. Best is trial 147 with value: 0.0039343442767858505.
# [I 2024-08-09 03:56:39,878] Trial 149 finished with value: 0.004295167978852987 and parameters: {'learning_rate': 2.6307470380610148e-05, 'hidden_size': 20, 'gamma': 0.9222393142085071}. Best is trial 147 with value: 0.0039343442767858505.
# [I 2024-08-09 03:56:46,392] Trial 150 finished with value: 0.0038586175069212914 and parameters: {'learning_rate': 2.0021074056732626e-05, 'hidden_size': 22, 'gamma': 0.9172537860046719}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:56:51,318] Trial 151 finished with value: 0.0096523966640234 and parameters: {'learning_rate': 3.4618166887416944e-05, 'hidden_size': 16, 'gamma': 0.9177670748716329}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:56:54,303] Trial 152 finished with value: 0.008152162656188011 and parameters: {'learning_rate': 2.7862513765205135e-05, 'hidden_size': 21, 'gamma': 0.9242779638636095}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:57:02,490] Trial 153 finished with value: 0.009107916615903378 and parameters: {'learning_rate': 2.0316651219683945e-05, 'hidden_size': 24, 'gamma': 0.9296277691246967}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:57:09,218] Trial 154 finished with value: 0.006713309790939093 and parameters: {'learning_rate': 2.463222284442581e-05, 'hidden_size': 19, 'gamma': 0.912341927858566}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:57:26,228] Trial 155 finished with value: 0.0061985827051103115 and parameters: {'learning_rate': 2.3013471033425373e-05, 'hidden_size': 23, 'gamma': 0.920552553976569}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:57:39,519] Trial 156 finished with value: 0.007252893876284361 and parameters: {'learning_rate': 8.851484968797634e-06, 'hidden_size': 16, 'gamma': 0.9257863058168111}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:57:45,328] Trial 157 finished with value: 0.004149682354182005 and parameters: {'learning_rate': 1.655690325871813e-05, 'hidden_size': 33, 'gamma': 0.872208012499287}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:58:12,750] Trial 158 finished with value: 0.005551947746425867 and parameters: {'learning_rate': 1.773270569082948e-05, 'hidden_size': 33, 'gamma': 0.919137001152018}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:58:22,693] Trial 159 finished with value: 0.004019333980977535 and parameters: {'learning_rate': 1.3090993906097735e-05, 'hidden_size': 36, 'gamma': 0.916086914124257}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:58:34,622] Trial 160 finished with value: 0.005704290699213743 and parameters: {'learning_rate': 1.5437980933223458e-05, 'hidden_size': 38, 'gamma': 0.9162201164489521}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:58:48,406] Trial 161 finished with value: 0.008367342874407768 and parameters: {'learning_rate': 1.2150236528129264e-05, 'hidden_size': 26, 'gamma': 0.9231558966231095}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:59:14,876] Trial 162 finished with value: 0.0066830916330218315 and parameters: {'learning_rate': 1.3593268320486608e-05, 'hidden_size': 32, 'gamma': 0.91120716002027}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 03:59:36,198] Trial 163 finished with value: 0.005264774430543184 and parameters: {'learning_rate': 1.8616606304898075e-05, 'hidden_size': 28, 'gamma': 0.9278736054542953}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:00:34,195] Trial 164 finished with value: 0.005282152444124222 and parameters: {'learning_rate': 6.550791232201023e-06, 'hidden_size': 44, 'gamma': 0.9156167496231441}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:00:53,726] Trial 165 finished with value: 0.004881653934717178 and parameters: {'learning_rate': 9.990061177821023e-06, 'hidden_size': 22, 'gamma': 0.9207126811838192}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:06,758] Trial 166 finished with value: 0.005671354942023754 and parameters: {'learning_rate': 3.122194945260224e-05, 'hidden_size': 36, 'gamma': 0.92390994629783}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:12,672] Trial 167 finished with value: 0.004122348502278328 and parameters: {'learning_rate': 2.2515333446134874e-05, 'hidden_size': 64, 'gamma': 0.9312427538996927}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:18,636] Trial 168 finished with value: 0.012796631082892418 and parameters: {'learning_rate': 2.3350236226698408e-05, 'hidden_size': 64, 'gamma': 0.9307181190791689}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:27,126] Trial 169 finished with value: 0.02132371813058853 and parameters: {'learning_rate': 2.011829261697357e-05, 'hidden_size': 32, 'gamma': 0.913533681953279}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:38,766] Trial 170 finished with value: 0.007082332391291857 and parameters: {'learning_rate': 1.6205361467334852e-05, 'hidden_size': 51, 'gamma': 0.8844173625701646}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:01:45,729] Trial 171 finished with value: 0.009259963408112526 and parameters: {'learning_rate': 2.866752917162792e-05, 'hidden_size': 26, 'gamma': 0.9343282604779249}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:02:08,947] Trial 172 finished with value: 0.007452924270182848 and parameters: {'learning_rate': 1.190087490002638e-05, 'hidden_size': 20, 'gamma': 0.9259256479532587}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:02:14,597] Trial 173 finished with value: 0.013076181523501873 and parameters: {'learning_rate': 2.1474495725902207e-05, 'hidden_size': 77, 'gamma': 0.9280818187537089}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:03:10,720] Trial 174 finished with value: 0.00518292561173439 and parameters: {'learning_rate': 5.283778943589182e-06, 'hidden_size': 58, 'gamma': 0.9206695067071667}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:03:37,843] Trial 175 finished with value: 0.005590280517935753 and parameters: {'learning_rate': 8.350449448402062e-06, 'hidden_size': 23, 'gamma': 0.8501906856675081}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:03:57,955] Trial 176 finished with value: 0.004782252479344606 and parameters: {'learning_rate': 2.5045859172795875e-05, 'hidden_size': 29, 'gamma': 0.9180147150383764}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:04:00,699] Trial 177 finished with value: 0.00906563363969326 and parameters: {'learning_rate': 6.359212416458772e-05, 'hidden_size': 19, 'gamma': 0.9229206569084171}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:04:08,825] Trial 178 finished with value: 0.004717401694506407 and parameters: {'learning_rate': 1.8252327722986522e-05, 'hidden_size': 25, 'gamma': 0.9306368880581795}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:04:16,186] Trial 179 finished with value: 0.009769189171493053 and parameters: {'learning_rate': 2.1577065586196413e-05, 'hidden_size': 35, 'gamma': 0.9358930365917415}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:04:24,394] Trial 180 finished with value: 0.00973635632544756 and parameters: {'learning_rate': 1.3024854498303407e-05, 'hidden_size': 29, 'gamma': 0.8624590960717804}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:04:43,895] Trial 181 finished with value: 0.004635699093341827 and parameters: {'learning_rate': 6.999992236134278e-06, 'hidden_size': 16, 'gamma': 0.8650992788147664}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:05:09,612] Trial 182 finished with value: 0.00506158173084259 and parameters: {'learning_rate': 1.0525008831107959e-05, 'hidden_size': 20, 'gamma': 0.8685709613016228}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:05:23,973] Trial 183 finished with value: 0.004025239497423172 and parameters: {'learning_rate': 8.818333380981974e-06, 'hidden_size': 23, 'gamma': 0.871455576805203}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:05:27,200] Trial 184 finished with value: 0.0047365715727210045 and parameters: {'learning_rate': 5.9578320737733916e-05, 'hidden_size': 25, 'gamma': 0.8717840017440536}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:05:34,573] Trial 185 finished with value: 0.003872375702485442 and parameters: {'learning_rate': 1.4550078943596704e-05, 'hidden_size': 22, 'gamma': 0.9326408178500648}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:05:46,491] Trial 186 finished with value: 0.006645488552749157 and parameters: {'learning_rate': 1.660651285354781e-05, 'hidden_size': 27, 'gamma': 0.8720623232782383}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:06:13,196] Trial 187 finished with value: 0.00511182053014636 and parameters: {'learning_rate': 1.53854419945248e-05, 'hidden_size': 31, 'gamma': 0.9323344331728295}. Best is trial 150 with value: 0.0038586175069212914.
# [I 2024-08-09 04:06:26,936] Trial 188 finished with value: 0.003556659910827875 and parameters: {'learning_rate': 1.4388268658707079e-05, 'hidden_size': 23, 'gamma': 0.8817490081053673}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:06:36,210] Trial 189 finished with value: 0.005750217474997044 and parameters: {'learning_rate': 1.2829528554563265e-05, 'hidden_size': 23, 'gamma': 0.8800636397233009}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:06:57,775] Trial 190 finished with value: 0.012034118175506592 and parameters: {'learning_rate': 9.83012496860942e-06, 'hidden_size': 114, 'gamma': 0.8925700182452503}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:07:02,135] Trial 191 finished with value: 0.004219705238938332 and parameters: {'learning_rate': 6.19200516938205e-05, 'hidden_size': 19, 'gamma': 0.9262636427320797}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:07:04,689] Trial 192 finished with value: 0.004230091813951731 and parameters: {'learning_rate': 6.586205201481662e-05, 'hidden_size': 23, 'gamma': 0.8751870548430957}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:07:34,566] Trial 193 finished with value: 0.006361095700412989 and parameters: {'learning_rate': 1.4307058706791073e-05, 'hidden_size': 27, 'gamma': 0.8783649851792517}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:07:40,836] Trial 194 finished with value: 0.00419071177020669 and parameters: {'learning_rate': 1.7279592670669955e-05, 'hidden_size': 18, 'gamma': 0.887772834542657}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:08:05,361] Trial 195 finished with value: 0.005155224818736315 and parameters: {'learning_rate': 1.1633429968342982e-05, 'hidden_size': 22, 'gamma': 0.8981587087577219}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:08:29,223] Trial 196 finished with value: 0.005559942219406366 and parameters: {'learning_rate': 4.666450101806926e-06, 'hidden_size': 31, 'gamma': 0.8820970798972094}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:08:49,533] Trial 197 finished with value: 0.005597088951617479 and parameters: {'learning_rate': 1.909353184868622e-05, 'hidden_size': 26, 'gamma': 0.8663769644495629}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:09:05,498] Trial 198 finished with value: 0.005443884525448084 and parameters: {'learning_rate': 1.3420344751700014e-05, 'hidden_size': 87, 'gamma': 0.8725861802689244}. Best is trial 188 with value: 0.003556659910827875.
# [I 2024-08-09 04:09:09,407] Trial 199 finished with value: 0.004507523961365223 and parameters: {'learning_rate': 5.825689051849477e-05, 'hidden_size': 16, 'gamma': 0.9235473584406784}. Best is trial 188 with value: 0.003556659910827875.
# Best hyperparameters: {'learning_rate': 1.4388268658707079e-05, 'hidden_size': 23, 'gamma': 0.8817490081053673}
# [*********************100%%**********************]  1 of 1 completed
# [I 2024-08-09 04:09:09,635] A new study created in memory with name: no-name-ad5baa51-56fa-4ae7-9bde-be7bd812b3f8
# ...
# [I 2024-08-09 13:47:30,500] Trial 6 finished with value: 0.00673255231231451 and parameters: {'learning_rate': 1.8451368855168333e-05, 'hidden_size': 140, 'gamma': 0.9643658095788137}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:47:36,874] Trial 7 finished with value: 0.03694897145032883 and parameters: {'learning_rate': 7.96231578719236e-05, 'hidden_size': 131, 'gamma': 0.8877551684255413}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:47:41,987] Trial 8 finished with value: 0.01049643475562334 and parameters: {'learning_rate': 9.538283466780299e-05, 'hidden_size': 56, 'gamma': 0.9103081068193742}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:47:49,629] Trial 9 finished with value: 0.005774817429482937 and parameters: {'learning_rate': 9.037270743986268e-05, 'hidden_size': 99, 'gamma': 0.9544535576662971}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:51:04,644] Trial 10 finished with value: 0.058665018528699875 and parameters: {'learning_rate': 1.0072159256082708e-06, 'hidden_size': 19, 'gamma': 0.9226202449157689}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:51:16,501] Trial 11 finished with value: 0.02576473541557789 and parameters: {'learning_rate': 4.9007551153193336e-05, 'hidden_size': 170, 'gamma': 0.8524788467001613}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:53:54,949] Trial 12 finished with value: 0.004962774459272623 and parameters: {'learning_rate': 2.7911142992227033e-06, 'hidden_size': 109, 'gamma': 0.8555858657025844}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:54:11,444] Trial 13 finished with value: 0.0026344393845647573 and parameters: {'learning_rate': 2.9748867405904157e-05, 'hidden_size': 164, 'gamma': 0.9235252156570602}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:54:20,138] Trial 14 finished with value: 0.008228096179664135 and parameters: {'learning_rate': 4.471833767010462e-05, 'hidden_size': 115, 'gamma': 0.8837309132191051}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:54:28,483] Trial 15 finished with value: 0.0050049093551933765 and parameters: {'learning_rate': 6.256773940391804e-05, 'hidden_size': 172, 'gamma': 0.9060757391041777}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:54:57,756] Trial 16 finished with value: 0.005236287135630846 and parameters: {'learning_rate': 1.697405720286809e-05, 'hidden_size': 82, 'gamma': 0.9395300857774265}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:55:13,111] Trial 17 finished with value: 0.013785929419100285 and parameters: {'learning_rate': 2.8666896776169057e-05, 'hidden_size': 134, 'gamma': 0.8692616189381082}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:55:21,474] Trial 18 finished with value: 0.01202619168907404 and parameters: {'learning_rate': 6.087791948267214e-05, 'hidden_size': 157, 'gamma': 0.9783952455536156}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:56:12,257] Trial 19 finished with value: 0.0017553727375343442 and parameters: {'learning_rate': 1.1416906255646553e-05, 'hidden_size': 183, 'gamma': 0.9358759064340092}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:56:26,361] Trial 20 finished with value: 0.007377339992672205 and parameters: {'learning_rate': 3.68615531799223e-05, 'hidden_size': 123, 'gamma': 0.9002574011238548}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:57:22,651] Trial 21 finished with value: 0.007785919588059187 and parameters: {'learning_rate': 9.041275580809407e-06, 'hidden_size': 184, 'gamma': 0.9319361921914407}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:58:16,059] Trial 22 finished with value: 0.0018680572975426912 and parameters: {'learning_rate': 9.244017728170377e-06, 'hidden_size': 181, 'gamma': 0.9628046965837852}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:58:34,155] Trial 23 finished with value: 0.003238629549741745 and parameters: {'learning_rate': 2.3140030057699817e-05, 'hidden_size': 153, 'gamma': 0.9357336017687921}. Best is trial 1 with value: 0.0007504741079173982.
# [I 2024-08-09 13:59:21,549] Trial 24 finished with value: 0.003952548839151859 and parameters: {'learning_rate': 1.1769391488383563e-05, 'hidden_size': 199, 'gamma': 0.914797456704914}. Best is trial 1 with value: 0.0007504741079173982.
# [W 2024-08-09 13:59:32,073] Trial 25 failed with parameters: {'learning_rate': 2.715840704816731e-05, 'hidden_size': 148, 'gamma': 0.9722484341800142} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "D:\TEMP\ipykernel_31296\2711466413.py", line 104, in objective
#     optimizer.step() #improve from loss, i.e backprop
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\lr_scheduler.py", line 130, in wrapper
#     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py", line 484, in wrapper
#     out = func(*args, **kwargs)
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py", line 89, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py", line 226, in step
#     adam(
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py", line 161, in maybe_fallback
#     return func(*args, **kwargs)
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py", line 766, in adam
#     func(
#   File "D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py", line 365, in _single_tensor_adam
#     step_t += 1
# KeyboardInterrupt
# [W 2024-08-09 13:59:32,771] Trial 25 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 137
#     132     return loss_test.item()
#     136 study = optuna.create_study(direction='minimize')  # or 'maximize' depending on your objective
# --> 137 study.optimize(objective, n_trials=200)
#     138 print("Best hyperparameters:", study.best_params)
#     139 with open(f"{ticker}_month_{i}.json", "w") as outfile:
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\study.py:451, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     348 def optimize(
#     349     self,
#     350     func: ObjectiveFuncType,
#    (...)
#     357     show_progress_bar: bool = False,
#     358 ) -> None:
#     359     """Optimize an objective function.
#     360
#     361     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     449             If nested invocation of this method occurs.
#     450     """
# --> 451     _optimize(
#     452         study=self,
#     453         func=func,
#     454         n_trials=n_trials,
#     455         timeout=timeout,
#     456         n_jobs=n_jobs,
#     457         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     458         callbacks=callbacks,
#     459         gc_after_trial=gc_after_trial,
#     460         show_progress_bar=show_progress_bar,
#     461     )
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\_optimize.py:62, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      60 try:
#      61     if n_jobs == 1:
# ---> 62         _optimize_sequential(
#      63             study,
#      64             func,
#      65             n_trials,
#      66             timeout,
#      67             catch,
#      68             callbacks,
#      69             gc_after_trial,
#      70             reseed_sampler_rng=False,
#      71             time_start=None,
#      72             progress_bar=progress_bar,
#      73         )
#      74     else:
#      75         if n_jobs == -1:
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\_optimize.py:159, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     156         break
#     158 try:
# --> 159     frozen_trial = _run_trial(study, func, catch)
#     160 finally:
#     161     # The following line mitigates memory problems that can be occurred in some
#     162     # environments (e.g., services that use computing containers such as GitHub Actions).
#     163     # Please refer to the following PR for further details:
#     164     # https://github.com/optuna/optuna/pull/325.
#     165     if gc_after_trial:
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\_optimize.py:247, in _run_trial(study, func, catch)
#     240         assert False, "Should not reach."
#     242 if (
#     243     frozen_trial.state == TrialState.FAIL
#     244     and func_err is not None
#     245     and not isinstance(func_err, catch)
#     246 ):
# --> 247     raise func_err
#     248 return frozen_trial
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\optuna\study\_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In[12], line 104, in objective(trial)
#     100 loss = criterion(outputs, y_train)
#     102 loss.backward() #calculates the loss of the loss function
# --> 104 optimizer.step() #improve from loss, i.e backprop
#     105 train_loss_array.append(loss.item())
#     106 models.append(model)
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\lr_scheduler.py:130, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     128 opt = opt_ref()
#     129 opt._opt_called = True  # type: ignore[union-attr]
# --> 130 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py:226, in Adam.step(self, closure)
#     214     beta1, beta2 = group["betas"]
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     223         state_steps,
#     224     )
# --> 226     adam(
#     227         params_with_grad,
#     228         grads,
#     229         exp_avgs,
#     230         exp_avg_sqs,
#     231         max_exp_avg_sqs,
#     232         state_steps,
#     233         amsgrad=group["amsgrad"],
#     234         has_complex=has_complex,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247     )
#     249 return loss
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py:766, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     763 else:
#     764     func = _single_tensor_adam
# --> 766 func(
#     767     params,
#     768     grads,
#     769     exp_avgs,
#     770     exp_avg_sqs,
#     771     max_exp_avg_sqs,
#     772     state_steps,
#     773     amsgrad=amsgrad,
#     774     has_complex=has_complex,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785 )
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\torch\optim\adam.py:365, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable)
#     359     assert (
#     360         param.device.type == step_t.device.type
#     361         and param.device.type in capturable_supported_devices
#     362     ), f"If capturable=True, params and state_steps must be on supported devices: {capturable_supported_devices}."
#     364 # update step
# --> 365 step_t += 1
#     367 if weight_decay != 0:
#     368     grad = grad.add(param, alpha=weight_decay)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\IPython\core\async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File D:\UserFiles\Projects\stock_market_model_lstm\lstm_env\lib\site-packages\IPython\core\interactiveshell.py:3311, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3305 interactivity = "none" if silent else self.ast_node_interactivity
#    3308 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3309        interactivity=interactivity, compiler=compiler, result=result)
# -> 3311 self.last_execution_succeeded = not has_raised
#    3312 self.last_execution_result = result
#    3314 # Reset this so later displayed values do not modify the
#    3315 # ExecutionResult
#
# KeyboardInterrupt:

# %%
hidden_size_arr= []
learning_rate_arr= []
gamma_arr= []

for i in range(1,9):
    f = open(f"{ticker}_month_{i}.json")
    data = json.load(f)
    hidden_size_arr.append(data['hidden_size'])
    learning_rate_arr.append(data['learning_rate'])
    gamma_arr.append(data['gamma'])
    f.close()

# %%
plt.plot(hidden_size_arr, label ='Hidden Size')
plt.plot(learning_rate_arr, label ='Learning Rate')
plt.plot(gamma_arr, label ='Gamma')
plt.legend()
plt.show()

# %%
plt.plot(learning_rate_arr, label ='Learning Rate')
plt.legend()
plt.show()

# %%
plt.plot(gamma_arr, label ='Gamma')
plt.legend()
plt.show()
